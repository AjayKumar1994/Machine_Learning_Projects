# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from matplotlib import rcParams

# %%
# kaggle zomato dataset 
data = pd.read_csv('zomato.csv')

# %%
data.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari
# 3          Buffet    Banashankari
# 4          Buffet    Banashankari

# %%
print("Percentage null or na values in df")
((data.isnull() | data.isna()).sum()*100/data.index.size).round(2)
# Out:
# Percentage null or na values in df
# url                             0.00
# address                         0.00
# name                            0.00
# online_order                    0.00
# book_table                      0.00
# rate                           15.03
# votes                           0.00
# phone                           2.34
# location                        0.04
# rest_type                       0.44
# dish_liked                     54.29
# cuisines                        0.09
# approx_cost(for two people)     0.67
# reviews_list                    0.00
# menu_item                       0.00
# listed_in(type)                 0.00
# listed_in(city)                 0.00
# dtype: float64

# %%
data.rate = data.rate.replace("NEW", np.nan)
data.dropna(how='any', inplace = True)

# %%
data.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari
# 3          Buffet    Banashankari
# 4          Buffet    Banashankari

# %%
# Rating distribution
# Most restaurants are rated between 3 and 4
plt.figure(figsize=(6,5))
rating=data['rate'].dropna().apply(lambda x : float(x.split('/')[0]) if (len(x)>3)  else np.nan ).dropna()
sns.distplot(rating,bins=20)
# Out:
# /home/joseph/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
del data['url']
del data['address']
del data['phone']
del data['location']
data.rename(columns={'approx_cost(for two people)': 'average_cost', 'listed_in(city)': 'locality','listed_in(type)': 'restaurant_type'}, inplace=True)
data.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#              rest_type                                         dish_liked  \
# 0        Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1        Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Cafe, Casual Dining  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3          Quick Bites                                        Masala Dosa
# 4        Casual Dining                                Panipuri, Gol Gappe
#
#                          cuisines average_cost  \
# 0  North Indian, Mughlai, Chinese          800
# 1     Chinese, North Indian, Thai          800
# 2          Cafe, Mexican, Italian          800
# 3      South Indian, North Indian          300
# 4        North Indian, Rajasthani          600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   restaurant_type      locality
# 0          Buffet  Banashankari
# 1          Buffet  Banashankari
# 2          Buffet  Banashankari
# 3          Buffet  Banashankari
# 4          Buffet  Banashankari

# %%
# Data cleaning to remove rating column with extra /5 
X = data
X.rate = X.rate.astype(str)
X.rate = X.rate.apply(lambda x: x.replace('/5',''))
X.rate = X.rate.apply(lambda x: float(x))

# %%
X.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#              rest_type                                         dish_liked  \
# 0        Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1        Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Cafe, Casual Dining  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3          Quick Bites                                        Masala Dosa
# 4        Casual Dining                                Panipuri, Gol Gappe
#
#                          cuisines average_cost  \
# 0  North Indian, Mughlai, Chinese          800
# 1     Chinese, North Indian, Thai          800
# 2          Cafe, Mexican, Italian          800
# 3      South Indian, North Indian          300
# 4        North Indian, Rajasthani          600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   restaurant_type      locality
# 0          Buffet  Banashankari
# 1          Buffet  Banashankari
# 2          Buffet  Banashankari
# 3          Buffet  Banashankari
# 4          Buffet  Banashankari

# %%
rcParams['figure.figsize'] = 15,7
g = sns.countplot(x="locality",data=data, palette = "Set1")
g.set_xticklabels(g.get_xticklabels(), rotation=90, ha="right")
g 
plt.title('locality',size = 20)
# Out:
# Text(0.5,1,'locality')

# %%
rcParams['figure.figsize'] = 15,7
g = sns.countplot(x="rest_type",data=data, palette = "Set1")
g.set_xticklabels(g.get_xticklabels(), rotation=90, ha="right")
g 
plt.title('rest_type',size = 20)
# Out:
# Text(0.5,1,'rest_type')

# %%
# online order option and rating of restaurant
plt.rcParams['figure.figsize'] = (3, 4)
plt.style.use('_classic_test')

X['online_order'].value_counts().plot.bar(color = 'cyan')
plt.title('Online orders', fontsize = 20)
plt.ylabel('Number of orders', fontsize = 15)
plt.show()

# %%
# Online order option gives higher rating
# X[['online_order','rate']].groupby(['rate']).sum(axis=0)
plt.rcParams['figure.figsize'] = (15, 9)
x = pd.crosstab(X['rate'], X['online_order'])
x.div(x.sum(1).astype(float), axis = 0).plot(kind = 'bar', stacked = True,color=['red','yellow'])
plt.title('online order vs rate', fontweight = 30, fontsize = 20)
plt.legend(loc="upper right")
plt.show()

# %%
# table booking option and rating of restaurant
plt.rcParams['figure.figsize'] = (7, 9)
plt.style.use('_classic_test')

X['book_table'].value_counts().plot.bar(color = 'cyan')
plt.title('Table booking', fontsize = 20)
plt.ylabel('Number of bookings', fontsize = 15)
plt.show()

# %%
# Cost distributions of various restaurants in city
X.head()
X.average_cost = X.average_cost.apply(lambda x: x.replace(',',''))
X.average_cost = X.average_cost.astype(int)
fig, ax = plt.subplots(figsize=[16,4])
sns.distplot(X['average_cost'],ax=ax)
ax.set_title('Cost Distrubution for all restaurants')
# Out:
# /home/joseph/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1,'Cost Distrubution for all restaurants')

# %%
#Finding best restaurants 

#Criteria : cheapest, high rated , reliable

# %%
X= X.drop_duplicates(subset='name',keep='first')
# dups_name = X1.pivot_table(index=['name'],aggfunc='size')
newdf=X[['name','average_cost','locality','rest_type','cuisines']].groupby(['average_cost'], sort = True)
newdf=newdf.filter(lambda x: x.mean() <= 1500)
newdf=newdf.sort_values(by=['average_cost'])
#newdf

# %%
newdf_rate=X[['name','rate']].groupby(['rate'], sort = True)
newdf_rate=newdf_rate.filter(lambda x: x.mean() >= 4.5)
newdf_rate=newdf_rate.sort_values(by=['rate'])
X.rate.value_counts()
X.rate.unique()
X.nunique()
# Out:
# name               3142
# online_order          2
# book_table            2
# rate                 31
# votes               965
# rest_type            70
# dish_liked         2903
# cuisines           1475
# average_cost         56
# reviews_list       3107
# menu_item           692
# restaurant_type       7
# locality             30
# dtype: int64

# %%
s1 = pd.merge(newdf, newdf_rate, how='inner', on=['name'])
print("Cheap restaurants with low cost,high rating \n")
s1
# Out:
# Cheap restaurants with low cost,high rating
#                                                 name  average_cost  \
# 0                               Brahmin's Coffee Bar           100
# 1                                       Taaza Thindi           100
# 2                                                CTR           150
# 3                              Chikkanna Tiffin Room           150
# 4                                       Veena Stores           150
# 5                                 O.G. Variar & Sons           200
# 6                          Mavalli Tiffin Room (MTR)           250
# 7                               Siddiqu Kabab Center           250
# 8                                  Mugful Of Stories           300
# 9                                  The Pancake Story           300
# 10                                     Shakes Theory           300
# 11                                             HOMMS           300
# 12                                           HVR Veg           300
# 13                                      Dock Frost'd           400
# 14                            Belgian Waffle Factory           400
# 15                                      Kurtoskalacs           400
# 16                          The Blue Wagon - Kitchen           400
# 17                                 XO Belgian Waffle           400
# 18                                  Milano Ice Cream           400
# 19                                   Lot Like Crepes           550
# 20                         The Hole in the Wall Cafe           600
# 21                                    Monet's Bistro           600
# 22                                            Onesta           600
# 23                              Avista Cafe Pizzeria           650
# 24                                       Suryawanshi           700
# 25                                ECHOES Koramangala           750
# 26                                        Here & Now           750
# 27                                       Pin Me Down           800
# 28                                      Dyu Art Cafe           800
# 29                                     Pot-O-Noodles           800
# ..                                               ...           ...
# 61                                  One For The Road          1300
# 62                                      Pasta Street          1300
# 63                                    The Reservoire          1300
# 64                                          Hammered          1300
# 65                                  Sultans of Spice          1300
# 66                         Sidewalk - The Garden Bar          1300
# 67  The London Curry House - The Royale Senate Hotel          1300
# 68                                        Jalsa Gold          1300
# 69                          Vapour Brewpub and Diner          1400
# 70                  The Terrace at Gilly's Redefined          1400
# 71                             Simon Says Brew Works          1400
# 72            Brew and Barbeque - A Microbrewery Pub          1400
# 73                                       Big Wong XL          1400
# 74                                          Flechazo          1400
# 75                      Levitate Brewery and Kitchen          1500
# 76                                              Toit          1500
# 77                                            Maziga          1500
# 78                                1131 Bar + Kitchen          1500
# 79                                  Buff Buffet Buff          1500
# 80                    Asia Kitchen By Mainland China          1500
# 81                                   The Permit Room          1500
# 82                                       Burma Burma          1500
# 83                                Koramangala Social          1500
# 84                                  The Big Barbeque          1500
# 85                                   The Black Pearl          1500
# 86                                 Opus Food Stories          1500
# 87                                           Chianti          1500
# 88                                   Sarjapur Social          1500
# 89                                     Toast & Tonic          1500
# 90                                         Communiti          1500
#
#                  locality                      rest_type  \
# 0            Basavanagudi                    Quick Bites
# 1            Banashankari                    Quick Bites
# 2            Malleshwaram                    Quick Bites
# 3            Brigade Road                    Quick Bites
# 4            Malleshwaram                    Quick Bites
# 5            Malleshwaram                         Bakery
# 6            Basavanagudi                    Quick Bites
# 7            Brigade Road                    Quick Bites
# 8            Kalyan Nagar                 Dessert Parlor
# 9                     BTM                 Dessert Parlor
# 10           Banashankari                  Beverage Shop
# 11            Brookefield                    Quick Bites
# 12           Malleshwaram                    Quick Bites
# 13            Brookefield  Beverage Shop, Dessert Parlor
# 14           Brigade Road                 Dessert Parlor
# 15                    BTM    Dessert Parlor, Quick Bites
# 16           Banashankari                           Cafe
# 17      Bannerghatta Road                 Dessert Parlor
# 18           Basavanagudi                 Dessert Parlor
# 19                    BTM           Cafe, Dessert Parlor
# 20  Koramangala 4th Block                           Cafe
# 21            Indiranagar                           Cafe
# 22           Banashankari            Casual Dining, Cafe
# 23           Kalyan Nagar                           Cafe
# 24              Bellandur                  Casual Dining
# 25                    BTM            Cafe, Casual Dining
# 26                    HSR                           Cafe
# 27           Basavanagudi                  Casual Dining
# 28                    BTM                           Cafe
# 29            Indiranagar                  Casual Dining
# ..                    ...                            ...
# 61           Kalyan Nagar                            Bar
# 62           Brigade Road                  Casual Dining
# 63                    BTM             Bar, Casual Dining
# 64           Brigade Road                      Pub, Cafe
# 65                    BTM                  Casual Dining
# 66            Brookefield             Bar, Casual Dining
# 67           Malleshwaram             Casual Dining, Bar
# 68              Bellandur                  Casual Dining
# 69              Bellandur              Microbrewery, Pub
# 70                    BTM    Microbrewery, Casual Dining
# 71                    BTM    Microbrewery, Casual Dining
# 72            Brookefield              Microbrewery, Pub
# 73                    BTM                  Casual Dining
# 74            Brookefield                  Casual Dining
# 75              Jayanagar    Microbrewery, Casual Dining
# 76            Indiranagar                   Microbrewery
# 77             Whitefield                  Casual Dining
# 78            Indiranagar             Bar, Casual Dining
# 79                    BTM             Casual Dining, Bar
# 80                    BTM             Casual Dining, Bar
# 81           Brigade Road             Casual Dining, Bar
# 82            Indiranagar                  Casual Dining
# 83                    BTM                         Lounge
# 84        Electronic City                  Casual Dining
# 85              Bellandur             Casual Dining, Bar
# 86              Bellandur             Bar, Casual Dining
# 87           Brigade Road                  Casual Dining
# 88              Bellandur             Bar, Casual Dining
# 89           Brigade Road                  Casual Dining
# 90           Brigade Road    Microbrewery, Casual Dining
#
#                                              cuisines  rate
# 0                                        South Indian   4.8
# 1                                        South Indian   4.7
# 2                                        South Indian   4.7
# 3                                        South Indian   4.5
# 4                                        South Indian   4.5
# 5                                    Bakery, Desserts   4.8
# 6                                        South Indian   4.5
# 7                                 North Indian, Rolls   4.5
# 8                                    Desserts, Bakery   4.6
# 9                                 Desserts, Beverages   4.6
# 10                                Beverages, Sandwich   4.5
# 11                    Chinese, Beverages, Momos, Thai   4.5
# 12                                       South Indian   4.5
# 13                                Beverages, Desserts   4.6
# 14                                           Desserts   4.9
# 15                                Desserts, Fast Food   4.6
# 16                                    Cafe, Beverages   4.6
# 17                                Desserts, Beverages   4.5
# 18                                Ice Cream, Desserts   4.5
# 19                        Cafe, Desserts, Continental   4.7
# 20                             Cafe, American, Burger   4.6
# 21                                    Cafe, Beverages   4.5
# 22                               Pizza, Cafe, Italian   4.6
# 23                                      Cafe, Italian   4.5
# 24                             Maharashtrian, Seafood   4.5
# 25  Chinese, American, Continental, Italian, North...   4.7
# 26                  Cafe, American, Burger, Beverages   4.6
# 27        Continental, Mexican, Chinese, North Indian   4.5
# 28                           Cafe, Italian, Fast Food   4.5
# 29                           Chinese, Asian, Japanese   4.5
# ..                                                ...   ...
# 61             Continental, North Indian, Finger Food   4.5
# 62                              Italian, Pizza, Salad   4.5
# 63  Continental, North Indian, Chinese, American, ...   4.5
# 64    North Indian, Thai, Japanese, Continental, Cafe   4.7
# 65                       North Indian, Mughlai, Salad   4.5
# 66           North Indian, Continental, Chinese, Thai   4.5
# 67                 Pizza, North Indian, Modern Indian   4.5
# 68                     North Indian, Mughlai, Italian   4.5
# 69                 North Indian, Continental, Italian   4.6
# 70      Continental, Finger Food, Asian, North Indian   4.6
# 71  Continental, American, Italian, Modern Indian,...   4.5
# 72              Continental, North Indian, BBQ, Steak   4.7
# 73                        Chinese, Sushi, Asian, Thai   4.5
# 74            Asian, Mediterranean, North Indian, BBQ   4.9
# 75             Finger Food, North Indian, Continental   4.5
# 76                           Italian, American, Pizza   4.7
# 77                                      Modern Indian   4.7
# 78          Continental, Asian, Italian, North Indian   4.6
# 79    North Indian, Chinese, Continental, Thai, Salad   4.5
# 80                        Asian, Chinese, Thai, Momos   4.9
# 81                                       South Indian   4.5
# 82                                     Asian, Burmese   4.7
# 83       American, North Indian, Chinese, Finger Food   4.6
# 84            BBQ, North Indian, Continental, Chinese   4.7
# 85         North Indian, European, Mediterranean, BBQ   4.8
# 86   Goan, Asian, North Indian, European, Continental   4.7
# 87                                            Italian   4.5
# 88       American, North Indian, Chinese, Finger Food   4.6
# 89                                    European, Asian   4.6
# 90                            Continental, BBQ, Salad   4.7
#
# [91 rows x 6 columns]

# %%
# X1.votes.describe()
newdf_votes=X[['name','votes']].groupby(['votes'], sort = True)
newdf_votes=newdf_votes.filter(lambda x: x.mean() >= 175)
newdf_votes=newdf_votes.sort_values(by=['votes'])
# newdf_votes

# %%
s = pd.merge(s1, newdf_votes, how='inner', on=['name'])
s=s.sort_values(by=['average_cost'])
print("Cheap restaurants,high rating,high votes")
s
# Out:
# Cheap restaurants,high rating,high votes
#                                                  name  average_cost  \
# 0                                Brahmin's Coffee Bar           100
# 1                                        Taaza Thindi           100
# 2                                                 CTR           150
# 3                               Chikkanna Tiffin Room           150
# 4                                        Veena Stores           150
# 5                                  O.G. Variar & Sons           200
# 6                           Mavalli Tiffin Room (MTR)           250
# 7                                   Mugful Of Stories           300
# 8                                               HOMMS           300
# 13                                   Milano Ice Cream           400
# 12                                  XO Belgian Waffle           400
# 10                                       Kurtoskalacs           400
# 9                              Belgian Waffle Factory           400
# 11                           The Blue Wagon - Kitchen           400
# 14                                    Lot Like Crepes           550
# 15                          The Hole in the Wall Cafe           600
# 16                                     Monet's Bistro           600
# 17                                             Onesta           600
# 18                               Avista Cafe Pizzeria           650
# 20                                         Here & Now           750
# 19                                 ECHOES Koramangala           750
# 22                                       Dyu Art Cafe           800
# 21                                        Pin Me Down           800
# 23                                         Baar Union           850
# 24                                       Market Table           900
# 25                                           Truffles           900
# 26            Bloomsbury's Global Kitchen & Bakehouse           900
# 35                                           Sea Rock          1000
# 34                                   House Of Commons          1000
# 32  SantÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃ...          1000
# ..                                                ...           ...
# 52                           Barbecue by Punjab Grill          1300
# 53                                   One For The Road          1300
# 55                                     The Reservoire          1300
# 56                                           Hammered          1300
# 57                                   Sultans of Spice          1300
# 58                          Sidewalk - The Garden Bar          1300
# 59   The London Curry House - The Royale Senate Hotel          1300
# 60                                         Jalsa Gold          1300
# 54                                       Pasta Street          1300
# 66                                           Flechazo          1400
# 64             Brew and Barbeque - A Microbrewery Pub          1400
# 65                                        Big Wong XL          1400
# 63                              Simon Says Brew Works          1400
# 61                           Vapour Brewpub and Diner          1400
# 62                   The Terrace at Gilly's Redefined          1400
# 79                                    Sarjapur Social          1500
# 78                                            Chianti          1500
# 77                                    The Black Pearl          1500
# 76                                   The Big Barbeque          1500
# 75                                 Koramangala Social          1500
# 74                                        Burma Burma          1500
# 73                                    The Permit Room          1500
# 71                                   Buff Buffet Buff          1500
# 70                                 1131 Bar + Kitchen          1500
# 69                                             Maziga          1500
# 68                                               Toit          1500
# 67                       Levitate Brewery and Kitchen          1500
# 80                                      Toast & Tonic          1500
# 72                     Asia Kitchen By Mainland China          1500
# 81                                          Communiti          1500
#
#                  locality                    rest_type  \
# 0            Basavanagudi                  Quick Bites
# 1            Banashankari                  Quick Bites
# 2            Malleshwaram                  Quick Bites
# 3            Brigade Road                  Quick Bites
# 4            Malleshwaram                  Quick Bites
# 5            Malleshwaram                       Bakery
# 6            Basavanagudi                  Quick Bites
# 7            Kalyan Nagar               Dessert Parlor
# 8             Brookefield                  Quick Bites
# 13           Basavanagudi               Dessert Parlor
# 12      Bannerghatta Road               Dessert Parlor
# 10                    BTM  Dessert Parlor, Quick Bites
# 9            Brigade Road               Dessert Parlor
# 11           Banashankari                         Cafe
# 14                    BTM         Cafe, Dessert Parlor
# 15  Koramangala 4th Block                         Cafe
# 16            Indiranagar                         Cafe
# 17           Banashankari          Casual Dining, Cafe
# 18           Kalyan Nagar                         Cafe
# 20                    HSR                         Cafe
# 19                    BTM          Cafe, Casual Dining
# 22                    BTM                         Cafe
# 21           Basavanagudi                Casual Dining
# 23                    HSR                     Bar, Pub
# 24                    BTM                         Cafe
# 25           Brigade Road                         Cafe
# 26            Brookefield         Cafe, Dessert Parlor
# 35           Malleshwaram                Casual Dining
# 34                    BTM                          Bar
# 32       Old Airport Road                Casual Dining
# ..                    ...                          ...
# 52           Malleshwaram                Casual Dining
# 53           Kalyan Nagar                          Bar
# 55                    BTM           Bar, Casual Dining
# 56           Brigade Road                    Pub, Cafe
# 57                    BTM                Casual Dining
# 58            Brookefield           Bar, Casual Dining
# 59           Malleshwaram           Casual Dining, Bar
# 60              Bellandur                Casual Dining
# 54           Brigade Road                Casual Dining
# 66            Brookefield                Casual Dining
# 64            Brookefield            Microbrewery, Pub
# 65                    BTM                Casual Dining
# 63                    BTM  Microbrewery, Casual Dining
# 61              Bellandur            Microbrewery, Pub
# 62                    BTM  Microbrewery, Casual Dining
# 79              Bellandur           Bar, Casual Dining
# 78           Brigade Road                Casual Dining
# 77              Bellandur           Casual Dining, Bar
# 76        Electronic City                Casual Dining
# 75                    BTM                       Lounge
# 74            Indiranagar                Casual Dining
# 73           Brigade Road           Casual Dining, Bar
# 71                    BTM           Casual Dining, Bar
# 70            Indiranagar           Bar, Casual Dining
# 69             Whitefield                Casual Dining
# 68            Indiranagar                 Microbrewery
# 67              Jayanagar  Microbrewery, Casual Dining
# 80           Brigade Road                Casual Dining
# 72                    BTM           Casual Dining, Bar
# 81           Brigade Road  Microbrewery, Casual Dining
#
#                                              cuisines  rate  votes
# 0                                        South Indian   4.8   2679
# 1                                        South Indian   4.7    651
# 2                                        South Indian   4.7   4408
# 3                                        South Indian   4.5    203
# 4                                        South Indian   4.5   2407
# 5                                    Bakery, Desserts   4.8   1156
# 6                                        South Indian   4.5   2896
# 7                                    Desserts, Bakery   4.6    274
# 8                     Chinese, Beverages, Momos, Thai   4.5    224
# 13                                Ice Cream, Desserts   4.5    197
# 12                                Desserts, Beverages   4.5    549
# 10                                Desserts, Fast Food   4.6    342
# 9                                            Desserts   4.9   1746
# 11                                    Cafe, Beverages   4.6    228
# 14                        Cafe, Desserts, Continental   4.7   1022
# 15                             Cafe, American, Burger   4.6   7113
# 16                                    Cafe, Beverages   4.5    197
# 17                               Pizza, Cafe, Italian   4.6   2556
# 18                                      Cafe, Italian   4.5    506
# 20                  Cafe, American, Burger, Beverages   4.6   1580
# 19  Chinese, American, Continental, Italian, North...   4.7   3197
# 22                           Cafe, Italian, Fast Food   4.5   3826
# 21        Continental, Mexican, Chinese, North Indian   4.5    784
# 23           Continental, Finger Food, Asian, Chinese   4.6    634
# 24        Cafe, Continental, Mediterranean, Beverages   4.5    546
# 25                      Cafe, American, Burger, Steak   4.5   3568
# 26  American, Cafe, Continental, French, Burger, M...   4.5    733
# 35  Mangalorean, Seafood, South Indian, North Indi...   4.6    514
# 34                   Continental, Asian, North Indian   4.8   4390
# 32                 Healthy Food, Salad, Mediterranean   4.9    246
# ..                                                ...   ...    ...
# 52                                                BBQ   4.7   1316
# 53             Continental, North Indian, Finger Food   4.5    755
# 55  Continental, North Indian, Chinese, American, ...   4.5   2540
# 56    North Indian, Thai, Japanese, Continental, Cafe   4.7   4639
# 57                       North Indian, Mughlai, Salad   4.5   3458
# 58           North Indian, Continental, Chinese, Thai   4.5   2949
# 59                 Pizza, North Indian, Modern Indian   4.5   3953
# 60                     North Indian, Mughlai, Italian   4.5   3421
# 54                              Italian, Pizza, Salad   4.5   1621
# 66            Asian, Mediterranean, North Indian, BBQ   4.9   2745
# 64              Continental, North Indian, BBQ, Steak   4.7   5746
# 65                        Chinese, Sushi, Asian, Thai   4.5    678
# 63  Continental, American, Italian, Modern Indian,...   4.5   1932
# 61                 North Indian, Continental, Italian   4.6   2726
# 62      Continental, Finger Food, Asian, North Indian   4.6    866
# 79       American, North Indian, Chinese, Finger Food   4.6   1193
# 78                                            Italian   4.5    340
# 77         North Indian, European, Mediterranean, BBQ   4.8   7023
# 76            BBQ, North Indian, Continental, Chinese   4.7    524
# 75       American, North Indian, Chinese, Finger Food   4.6   4650
# 74                                     Asian, Burmese   4.7   1594
# 73                                       South Indian   4.5   1573
# 71    North Indian, Chinese, Continental, Thai, Salad   4.5   3125
# 70          Continental, Asian, Italian, North Indian   4.6   2785
# 69                                      Modern Indian   4.7    292
# 68                           Italian, American, Pizza   4.7  14956
# 67             Finger Food, North Indian, Continental   4.5    456
# 80                                    European, Asian   4.6   1082
# 72                        Asian, Chinese, Thai, Momos   4.9   2178
# 81                            Continental, BBQ, Salad   4.7   3894
#
# [82 rows x 7 columns]
